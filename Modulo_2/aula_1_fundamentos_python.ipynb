# %% [markdown]
# #Módulo 2 - Mentorama Data Science do Zero ao Pró

# %% [markdown]
# **Variáveis**
# --
# *   Como definir variáveis no Python:

# %%
nome = "Douglas" #definição da variável sempre o nome = valor (o "=" é chamado  de operador de atribuição)

# %%
idade = 39

# %%
altura = 1.79

# %%
e_matematica = True

# %% [markdown]
# **Como sabemos o valor que gravamos na variável?**

# %%
nome #digitar o nome da variável e clicar shft+Enter
# Out:
# 'Douglas'

# %%
nome
idade #se colocar as duas variáveis em um bloco só ele mostrará apenas o valor do última variável
# Out:
# 39

# %%
nome, altura #para mostrar as duas variáveis temos que fazer dessa forma
# Out:
# ('Douglas', 1.79)

# %%
print(nome)
print(idade)
# Out:
# Douglas
# 39

# %%
print("O valor da variável nome é: ",nome)
# Out:
# O valor da variável nome é:  Douglas

# %% [markdown]
# **E como sabemos o tipo da variável?**
# --
# * Para isso usamos a função type();

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
type(altura)
# Out:
# float

# %%
type(e_matematica)
# Out:
# bool

# %% [markdown]
# **Conversão de Tipos**
# --
# - Supondo que agora queremos não apenas dizer os anos, mas os anos e meses, então poderíamos escrever por exemplo: 39.4, ou 39 anos e 4 meses.

# %%
type(idade) #queremos converter o valor int para float
# Out:
# int

# %%
idade = float(idade) #convertendo o tipo de variável

# %%
type(idade)
# Out:
# float

# %%
idade = 39.4

# %%
idade
# Out:
# 39.4

# %%
float(e_matematica) #true = 1, false = 0
# Out:
# 1.0

# %% [markdown]
# **Sobreescrevendo uma variável**
# --

# %%
altura
# Out:
# 1.79

# %%
altura = "olá"

# %%
altura
# Out:
# 'olá'

# %% [markdown]
# -importante tomar cuidado quando se estiver escrevendo código pois você pode perder o valor dessa variável
